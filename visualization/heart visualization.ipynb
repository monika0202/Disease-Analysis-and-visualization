# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
import seaborn as sns

# %%
col= ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate_achieved',
       'exercise_induced_angina', 'st_depression', 'st_slope', 'num_major_vessels', 'thalassemia', 'target']

# %%
data=pd.read_csv('/home/dell/python_machine_learning/disease/csv/heart.csv',names=col, header = 0)
data.head()
# Out:
#    age  sex  chest_pain_type  resting_blood_pressure  cholesterol  \
# 0   63    1                3                     145          233
# 1   37    1                2                     130          250
# 2   41    0                1                     130          204
# 3   56    1                1                     120          236
# 4   57    0                0                     120          354
#
#    fasting_blood_sugar  rest_ecg  max_heart_rate_achieved  \
# 0                    1         0                      150
# 1                    0         1                      187
# 2                    0         0                      172
# 3                    0         1                      178
# 4                    0         1                      163
#
#    exercise_induced_angina  st_depression  st_slope  num_major_vessels  \
# 0                        0            2.3         0                  0
# 1                        0            3.5         0                  0
# ...

# %%
plt.rcParams['figure.figsize'] = (20, 15)
plt.style.use('ggplot')

sns.heatmap(data.corr(), annot = True, cmap = 'Wistia')
plt.title('Heatmap for the Dataset', fontsize = 20)
plt.show()

# %%
fig = plt.figure(figsize=(8,6))

sns.distplot(data['age'], color = 'cyan')
plt.title('Distribution of Age', fontsize = 20)
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(data['target'], data['resting_blood_pressure'], palette = 'viridis')
plt.title('Relation of tresbps with target', fontsize = 20)
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = sns.lineplot(x="target", y="resting_blood_pressure", data=data, color = 'green', hue = 'sex', style = 'sex')
plt.title('Checking relation of tresbps with genders to target', fontsize = 20, fontweight = 30)
plt.show()

# %%
sns.set_style("white")
xx=data["cholesterol"].values.reshape(1,-1)
yy=data["resting_blood_pressure"].values.reshape(1,-1)
aa=data["age"].values.reshape(1,-1)

fig = plt.figure(figsize=(12,9))
ax = plt.axes(projection="3d")

ax.scatter3D(xx, yy,data['age'],cmap='hsv',s=200, c='#809fff')

plt.title('Cholestrol vs Heart Rate vs Age')
ax.set_xlabel("Cholestrol")
ax.set_ylabel("Heart Rate")
ax.set_zlabel("Age")

#ax.plot_surface(xx, yy, zz, alpha=0.4)
plt.show()

# %%
g = sns.pairplot(data, plot_kws={'color':'green'})

# %%
g = sns.pairplot(data[['max_heart_rate_achieved','st_slope','sex', 'thalassemia']], hue = 'sex')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.figure(figsize=(12,9))
plt.plot(data["st_depression"])
plt.show()

# %%
sns.jointplot(x=data.age, y=data.sex, data=data,color='#4da6ff', kind="kde");

# %%
ax1 = plt.subplots(figsize =(20,10))
sns.pointplot(x='age',y='resting_blood_pressure',data=data,color='lime',alpha=0.8)
sns.pointplot(x='age',y='cholesterol',data=data,color='red',alpha=0.8)
sns.pointplot(x='age',y='thalassemia',data=data,color='blue',alpha=0.8)

# %%
labels = data.chest_pain_type.value_counts().index
colors = ['green','yellow','blue','red']
explode = [0,0,0,0]
sizes = data.chest_pain_type.value_counts().values

plt.figure(0,figsize = (7,7))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Target People According to Chestpain Type',color = 'blue',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Target People According to Chestpain Type')
